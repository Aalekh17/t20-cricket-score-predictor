# %%
import pandas as pd
import pickle
import numpy as np

# %%
df=pickle.load(open('dataset_level2.pkl','rb'))

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                7922
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2841
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1328
# Sydney Cricket Ground                       623
# Adelaide Oval                               373
# Harare Sports Club                          372
# Sylhet International Cricket Stadium        128
# Sharjah Cricket Stadium                     127
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0              2      England    Australia   0.1     2                0
# 1              2      England    Australia   0.2     0                0
# 2              2      England    Australia   0.3     1                0
# 3              2      England    Australia   0.4     4                0
# 4              2      England    Australia   0.5     2                0
# ...          ...          ...          ...   ...   ...              ...
# 156507      1305    Sri Lanka    Australia  19.3     1                0
# 156508      1305    Sri Lanka    Australia  19.4     0                0
# 156509      1305    Sri Lanka    Australia  19.5     0      DM de Silva
# 156510      1305    Sri Lanka    Australia  19.6     2                0
# 156511      1305    Sri Lanka    Australia  19.7     1                0
#
#            city
# 0        Hobart
# 1        Hobart
# 2        Hobart
# 3        Hobart
# ...

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 124            3      England    Australia   0.1     2                0
# 125            3      England    Australia   0.2     1                0
# 126            3      England    Australia   0.3     0                0
# 127            3      England    Australia   0.4     1                0
# 128            3      England    Australia   0.5     3                0
# ...          ...          ...          ...   ...   ...              ...
# 156507      1305    Sri Lanka    Australia  19.3     1                0
# 156508      1305    Sri Lanka    Australia  19.4     0                0
# 156509      1305    Sri Lanka    Australia  19.5     0      DM de Silva
# 156510      1305    Sri Lanka    Australia  19.6     2                0
# 156511      1305    Sri Lanka    Australia  19.7     1                0
#
#              city
# 124     Melbourne
# 125     Melbourne
# 126     Melbourne
# 127     Melbourne
# ...

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\3344088627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\190681986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 124            3      England    Australia   0.1     2                0
# 125            3      England    Australia   0.2     1                0
# 126            3      England    Australia   0.3     0                0
# 127            3      England    Australia   0.4     1                0
# 128            3      England    Australia   0.5     3                0
# ...          ...          ...          ...   ...   ...              ...
# 156507      1305    Sri Lanka    Australia  19.3     1                0
# 156508      1305    Sri Lanka    Australia  19.4     0                0
# 156509      1305    Sri Lanka    Australia  19.5     0      DM de Silva
# 156510      1305    Sri Lanka    Australia  19.6     2                0
# 156511      1305    Sri Lanka    Australia  19.7     1                0
#
#              city  current_score
# 124     Melbourne              2
# 125     Melbourne              3
# ...

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\2777558413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\2777558413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# 124            3      England    Australia   0.1     2                0
# 125            3      England    Australia   0.2     1                0
# 126            3      England    Australia   0.3     0                0
# 127            3      England    Australia   0.4     1                0
# 128            3      England    Australia   0.5     3                0
# ...          ...          ...          ...   ...   ...              ...
# ...

# %%
df['balls_left'] = 120 - df['balls_bowled']
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\2304996896.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\2304996896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#         match_id batting_team bowling_team  ball  runs player_dismissed  \
# ...

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# Convert to numeric (already int, but safe)
df['player_dismissed'] = df['player_dismissed'].astype(int)

# Groupwise cumulative sum only on that column
df['player_dismissed_cum'] = df.groupby('match_id')['player_dismissed'].cumsum()

# Wickets left
df['wickets_left'] = 10 - df['player_dismissed_cum']
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\1122442204.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\1122442204.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype(int)
# ...

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 124            3      England    Australia   0.1     2                 0
# 125            3      England    Australia   0.2     1                 0
# 126            3      England    Australia   0.3     0                 0
# 127            3      England    Australia   0.4     1                 0
# 128            3      England    Australia   0.5     3                 0
# ...          ...          ...          ...   ...   ...               ...
# 156507      1305    Sri Lanka    Australia  19.3     1                 0
# 156508      1305    Sri Lanka    Australia  19.4     0                 0
# 156509      1305    Sri Lanka    Australia  19.5     0                 1
# 156510      1305    Sri Lanka    Australia  19.6     2                 0
# 156511      1305    Sri Lanka    Australia  19.7     1                 0
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#         match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 124            3      England    Australia   0.1     2                 0
# 125            3      England    Australia   0.2     1                 0
# 126            3      England    Australia   0.3     0                 0
# 127            3      England    Australia   0.4     1                 0
# 128            3      England    Australia   0.5     3                 0
# ...          ...          ...          ...   ...   ...               ...
# 156507      1305    Sri Lanka    Australia  19.3     1                 0
# 156508      1305    Sri Lanka    Australia  19.4     0                 0
# 156509      1305    Sri Lanka    Australia  19.5     0                 1
# 156510      1305    Sri Lanka    Australia  19.6     2                 0
# 156511      1305    Sri Lanka    Australia  19.7     1                 0
#
#              city  current_score over ball_no  balls_bowled  balls_left  \
# ...

# %%
df['match_id'] = df['match_id'].astype(int)
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
groups = df.groupby('match_id')

match_ids = df['match_id'].unique()
last_five = []
for id in match_ids:
    run_series = groups.get_group(id)['runs']  
    last_five.extend(run_series.rolling(window=30).sum().values.tolist())
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\1404311638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['match_id'] = df['match_id'].astype(int)
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\1404311638.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

# %%
df['last_five'] = last_five
# Out:
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_3220\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team      city  current_score  balls_left  \
# 24693    Sri Lanka  New Zealand  Auckland            115          13
# 4609      Pakistan  West Indies   Karachi            118          47
#
#        wickets_left       crr  last_five  runs_x
# 24693             2  6.448598       49.0     115
# 4609              9  9.698630       53.0     205

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#       batting_team  bowling_team        city  current_score  balls_left  \
# 32384    Sri Lanka         India     Colombo            152          17
# 2215       England         India  Manchester             61          75
# 43549     Pakistan    Bangladesh      Mirpur             61          71
# 57521        India    Bangladesh       Dhaka             98          29
# 56362  New Zealand      Pakistan  Chandigarh             62          76
# ...            ...           ...         ...            ...         ...
# 27120   Bangladesh      Pakistan   Cape Town             61          73
# 15533      England   West Indies  Bridgetown             36          87
# 29842      England      Pakistan      London             63          85
# 21427     Pakistan   West Indies     Karachi            171           2
# 3182         India  South Africa   Cape Town             49          89
#
#        wickets_left        crr  last_five
# 32384             6   8.854369       55.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error

# %%
trf = ColumnTransformer([
    ('trf',OneHotEncoder(sparse_output=False,drop='first',handle_unknown='ignore'),['batting_team','bowling_team','city'])
]
,remainder='passthrough')

# %%
pipe = Pipeline(steps=[
    ('step1',trf),
    ('step2',StandardScaler()),
    ('step3',XGBRegressor(n_estimators=1000,learning_rate=0.2,max_depth=12,random_state=1))
])

# %%
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9874441027641296
# 1.7698639631271362

# %%
pickle.dump(pipe,open('pipe3.pkl','wb'))

# %%
teams
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 teams
#
# NameError: name 'teams' is not defined
